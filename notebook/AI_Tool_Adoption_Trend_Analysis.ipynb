# %%
# !pip install pandas numpy matplotlib seaborn scipy plotly

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import ttest_ind

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(
    "AI_Tool_Adoption_Dataset_5000.csv"
)

df.head()

# %%
import os

print(os.listdir())

# %%
from google.colab import files

uploaded = files.upload()

# %%
import os
print(os.listdir())

# %%
import pandas as pd

df = pd.read_csv("AI_Tool_Adoption_Dataset_5000.csv")
df.head()

# %%
df = pd.read_csv("AI_Tool_Adoption_Dataset_5000.csv")

# %%
print("Rows, Columns:", df.shape)

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()

# %%
df['Organization_ID'].nunique()

# %%
df['AI_Tool'].value_counts()

# %%
import matplotlib.pyplot as plt

df['AI_Tool'].value_counts().plot(
    kind='bar'
)

plt.title("Most Used AI Tools")
plt.show()

# %%
df['Industry'].value_counts()

# %%
import seaborn as sns

plt.figure(figsize=(10,5))

sns.countplot(
    x='Industry',
    data=df
)

plt.xticks(rotation=45)

plt.title(
    "AI Adoption by Industry"
)

plt.show()

# %%
df['Productivity_Gain_Percent'].mean()

# %%
df['Productivity_Gain_Percent'].median()

# %%
df['Productivity_Gain_Percent'].std()

# %%
df['Productivity_Gain_Percent'].quantile(
    [0.25,0.5,0.75]
)

# %%
df['AI_Usage_Hours_Per_Week'].mean()

# %%
df['Company_Size'].value_counts()

# %%
df['Company_Size'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title(
    'Company Size Distribution'
)

plt.show()

# %%
industry_usage = df.groupby(
    'Industry'
)['AI_Usage_Hours_Per_Week'].mean()

industry_usage

# %%
industry_usage.plot(
    kind='bar',
    figsize=(8,5)
)

plt.title(
    "Industry vs AI Adoption"
)

plt.ylabel(
    "Average Usage Hours"
)

plt.show()

# %%
sns.boxplot(
    x='Company_Size',
    y='AI_Usage_Hours_Per_Week',
    data=df
)

plt.show()

# %%
tool_sat = df.groupby(
    'AI_Tool'
)['Satisfaction_Score'].mean()

tool_sat

# %%
tool_sat.plot(
    kind='bar'
)

plt.title(
    "AI Tool vs Satisfaction"
)

plt.show()

# %%
year_growth = df.groupby(
    'Adoption_Year'
).size()

year_growth

# %%
year_growth.plot(
    marker='o'
)

plt.title(
    "AI Adoption Growth"
)

plt.show()

# %%
sns.scatterplot(
    x='Employee_Count',
    y='AI_Usage_Hours_Per_Week',
    data=df
)

plt.show()

# %%
corr = df[
[
'Employee_Count',
'AI_Investment_USD',
'Productivity_Gain_Percent',
'Annual_Savings_USD',
'Satisfaction_Score',
'AI_Usage_Hours_Per_Week',
'ROI_Percent'
]
].corr()

corr

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,7))

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)

plt.title(
    'Correlation Heatmap'
)

plt.show()

# %%
plt.savefig(
    'correlation_heatmap.png',
    bbox_inches='tight'
)

# %%
from scipy.stats import ttest_ind

small = df[
df['Company_Size']=='Small'
]['AI_Usage_Hours_Per_Week']

large = df[
df['Company_Size']=='Large'
]['AI_Usage_Hours_Per_Week']

t_stat,p_value = ttest_ind(
small,
large
)

print("T Statistic =",t_stat)

print("P Value =",p_value)

# %%
if p_value < 0.05:

    print(
        "Reject H0"
    )

    print(
        "Company size significantly impacts AI adoption."
    )

else:

    print(
        "Fail to Reject H0"
    )

    print(
        "Company size does not significantly impact AI adoption."
    )

# %%
import numpy as np

conditions = [

df['AI_Usage_Hours_Per_Week'] > 30,

df['AI_Usage_Hours_Per_Week'] > 15,

df['AI_Usage_Hours_Per_Week'] <= 15

]

choices = [

'AI Leaders',

'Early Adopters',

'Slow Adopters'

]

df['Segment'] = np.select(
conditions,
choices,
default='Slow Adopters'
)

df['Segment'].value_counts()

# %%
df['Segment'].value_counts().plot(
kind='pie',
autopct='%1.1f%%',
figsize=(7,7)
)

plt.title(
'Organization Segmentation'
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
x='AI_Tool',
data=df
)

plt.title(
'AI Tool Adoption'
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
x='AI_Tool',
y='Satisfaction_Score',
data=df
)

plt.title(
'AI Tool vs Satisfaction'
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
x='AI_Investment_USD',
y='Annual_Savings_USD',
data=df
)

plt.title(
'Investment vs Savings'
)

plt.show()

# %%
corr

# %%
print("P Value =",p_value)

# %%
# ==========================
# FINAL PROJECT REPORT
# ==========================

total_orgs = len(df)

most_used_tool = df['AI_Tool'].value_counts().idxmax()

top_industry = df['Industry'].value_counts().idxmax()

avg_productivity = round(
    df['Productivity_Gain_Percent'].mean(),2
)

avg_usage = round(
    df['AI_Usage_Hours_Per_Week'].mean(),2
)

avg_roi = round(
    df['ROI_Percent'].mean(),2
)

avg_satisfaction = round(
    df['Satisfaction_Score'].mean(),2
)

report = f"""

AI TOOL ADOPTION TREND ANALYSIS
=============================================

1. PROBLEM STATEMENT
---------------------------------------------
Artificial Intelligence tools are rapidly transforming
organizations across industries. This project analyzes
AI adoption trends, productivity impact, user satisfaction,
investment patterns, and organizational behavior to
support data-driven business decisions.

2. DATASET OVERVIEW
---------------------------------------------
Total Organizations Analysed : {total_orgs}

Dataset Features:
- Industry
- Company Size
- Employee Count
- AI Tool
- Adoption Year
- AI Investment
- Productivity Gain
- Annual Savings
- Satisfaction Score
- AI Usage Hours
- ROI
- Adoption Status

3. DATA UNDERSTANDING
---------------------------------------------
The dataset was examined for:

✓ Missing Values
✓ Duplicate Records
✓ Data Types
✓ Statistical Summary

Result:
No missing values were found and the dataset
was ready for analysis.

4. DESCRIPTIVE STATISTICS
---------------------------------------------
Average Productivity Gain (%) : {avg_productivity}

Average AI Usage Hours/Week : {avg_usage}

Average Satisfaction Score : {avg_satisfaction}

Average ROI (%) : {avg_roi}

5. TREND ANALYSIS
---------------------------------------------
Most Adopted AI Tool:
{most_used_tool}

Leading Industry:
{top_industry}

Observations:

• AI adoption has increased significantly
  over recent years.

• Larger organizations generally invest
  more in AI technologies.

• Higher AI usage is associated with
  improved productivity.

6. CORRELATION ANALYSIS
---------------------------------------------
Correlation analysis was performed between:

- Employee Count
- AI Investment
- Productivity Gain
- Annual Savings
- Satisfaction
- AI Usage Hours
- ROI

Key Findings:

• AI investment positively influences savings.

• AI usage contributes to productivity gains.

• Organizations with higher AI usage tend
  to report better satisfaction scores.

7. HYPOTHESIS TESTING
---------------------------------------------
Null Hypothesis (H0):
Company size has no impact on AI adoption.

Alternative Hypothesis (H1):
Company size significantly impacts AI adoption.

A T-Test was performed between Small and
Large organizations.

Decision:
Based on the obtained p-value,
the hypothesis result was interpreted.

8. ORGANIZATION SEGMENTATION
---------------------------------------------
Organizations were categorized into:

• AI Leaders
• Early Adopters
• Slow Adopters

Segmentation helps identify which companies
are leading AI transformation efforts.

9. BUSINESS INSIGHTS
---------------------------------------------
1. AI adoption continues to grow rapidly.

2. ChatGPT emerged as one of the dominant
   AI solutions.

3. Organizations with higher investments
   achieve greater savings.

4. Productivity improves as AI usage increases.

5. Early AI adopters gain competitive advantages.

6. High ROI organizations should continue
   expanding AI initiatives.

10. RECOMMENDATIONS
---------------------------------------------
• Increase AI training programs.

• Invest in high-performing AI tools.

• Encourage AI adoption across departments.

• Track ROI regularly to optimize investments.

• Use AI-driven automation for operational
  efficiency.

11. FUTURE SCOPE
---------------------------------------------
• Predict future AI adoption using Machine Learning.

• Develop AI investment recommendation systems.

• Build industry-specific adoption models.

• Analyze emerging Generative AI technologies.

=============================================
END OF REPORT
=============================================

"""

print(report)

with open(
    "AI_Tool_Adoption_Report.txt",
    "w"
) as f:

    f.write(report)

print(
    "\nReport Saved Successfully!"
)

# %%
from google.colab import files

files.download(
    "AI_Tool_Adoption_Report.txt"
)
